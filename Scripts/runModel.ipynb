# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action = "ignore", category = FutureWarning)

from badlands.model import Model as badlandsModel

# %%
# !pwd
# !ls ../preprocess/run/
# Out:
# /live/share/Africa/WorkflowInputs/Models/AY18/run
# Actualtopo_AY18_10.csv			correctedWaterTopo2_8.csv
# Cli_M5_015.csv				correctedWaterTopo4_8.csv
# Cli_M5_1520.csv				correctedWaterTopo5.csv
# Cli_M5_2035.csv				correctedWaterTopo7.csv
# Cli_M5_3540.csv				correctedWaterTopo75.csv
# Cli_M5_35402.csv			correctedWaterTopo8.csv
# Cli_fixed.csv				correctedWaterTopo9.csv
# PALEOtopoWithoutCorrection2_10.csv	correctedWaterdef4_8.csv
# PALEOtopoWithoutCorrection4_10.csv	correctedWaterdef7.csv
# PALEOtopoWithoutCorrection4_10.csv.csv	correctedWaterdef8.csv
# PALEOtopoWithoutCorrection_10.csv	correctedWaterdef9.csv
# PALEOtopoWithoutCorrection_10.csv.csv	ero10.csv
# TeMapgpml.csv				ero11.csv
# TeMapgpmlmeters.csv			ero12.csv
# Tecto_)_0Ma.csv				ero133.csv
# Tecto_)_10Ma.csv			ero5.csv
# Tecto_)_20Ma.csv			ero7_12.csv
# Tecto_)_30Ma.csv			ero7_15.csv
# Tecto_10_0Ma.csv			ero82_16.csv
# Tecto_10_10Ma.csv			ero83_16.csv
# Tecto_10_20Ma.csv			ero8_16.csv
# Tecto_10_30Ma.csv			ero9.csv
# Tecto_2_0Ma.csv				removedSed.csv
# Tecto_2_10Ma.csv			removedSed2_8.csv
# Tecto_2_20Ma.csv			removedSed4_8.csv
# Tecto_2_30Ma.csv			removedSedDef2_8.csv
# Tecto_4_0Ma.csv				removedSedDef4_8.csv
# Tecto_4_10Ma.csv			removedSedDef5.csv
# Tecto_4_20Ma.csv			removedSedDef7.csv
# Tecto_4_30Ma.csv			removedSedDef75.csv
# Tegpml.csv				removedSedDef8.csv
# Tegpmlmeters.csv			removedSedDef9.csv
# ThicknessMapgpml.csv			removedSedDefmulti2_8.csv
# Thicknessgpml.csv

# %% [markdown]
# ## Starting pyBadlands
#
# First, we initialise the model and set the path to the **XmL** input file:
#
# + **input.xml**
#
# > You can edit the **XmL** configuration file directly in the _Jupyter environment_ by clicking on it in the `tree` and changing in the **url** the **view** to **edit**.

# %%
# Initialise model
model = badlandsModel()

# Define the XmL input file
model.load_xml('52Cdt2.xml')

# %% [markdown]
# ## Running pyBadlands
#
# We can run the model for a given period. The end time in the **XmL** input file is set to _130 ky_ but you might want to run the model for a coupled of iterations and check the output before running the model for the entire simulation time. This is done by putting the time in the **run_to_time** function.
#
# Here we go for the full time directly...

# %%
model.run_to_time(0)
# Out:
#    - Writing outputs (1.23 seconds; tNow = -40000000.0)
#    - Compute flexural isostasy 122.31 seconds
# tNow = -39800000.0 (step took 123.21 seconds)
#    - Compute flexural isostasy 131.68 seconds
#    - Writing outputs (1.34 seconds; tNow = -39800000.0)
#    - Compute flexural isostasy 134.73 seconds
# tNow = -39600000.0 (step took 135.65 seconds)
#    - Compute flexural isostasy 119.75 seconds
#    - Writing outputs (1.19 seconds; tNow = -39600000.0)
#    - Compute flexural isostasy 135.35 seconds
# tNow = -39400000.0 (step took 136.26 seconds)
#    - Compute flexural isostasy 125.68 seconds
#    - Writing outputs (1.17 seconds; tNow = -39400000.0)
#    - Compute flexural isostasy 133.13 seconds
# tNow = -39200000.0 (step took 134.07 seconds)
#    - Compute flexural isostasy 115.58 seconds
#    - Writing outputs (1.17 seconds; tNow = -39200000.0)
#    - Compute flexural isostasy 127.30 seconds
# tNow = -39000000.0 (step took 128.34 seconds)
#    - Compute flexural isostasy 127.84 seconds
#    - Writing outputs (1.13 seconds; tNow = -39000000.0)
#    - Compute flexural isostasy 149.23 seconds
# tNow = -38800000.0 (step took 151.24 seconds)
#    - Compute flexural isostasy 105.96 seconds
#    - Writing outputs (1.11 seconds; tNow = -38800000.0)
#    - Compute flexural isostasy 145.91 seconds
# tNow = -38600000.0 (step took 148.14 seconds)
#    - Compute flexural isostasy 146.88 seconds
#    - Writing outputs (1.11 seconds; tNow = -38600000.0)
#    - Compute flexural isostasy 136.78 seconds
# tNow = -38400000.0 (step took 138.95 seconds)
#    - Compute flexural isostasy 114.44 seconds
#    - Writing outputs (1.14 seconds; tNow = -38400000.0)
#    - Compute flexural isostasy 127.94 seconds
# tNow = -38200000.0 (step took 130.13 seconds)
#    - Compute flexural isostasy 130.76 seconds
#    - Writing outputs (1.21 seconds; tNow = -38200000.0)
#    - Compute flexural isostasy 165.18 seconds
# tNow = -38000000.0 (step took 167.51 seconds)
#    - Compute flexural isostasy 129.86 seconds
#    - Writing outputs (1.17 seconds; tNow = -38000000.0)
#    - Compute flexural isostasy 140.51 seconds
# tNow = -37800000.0 (step took 142.84 seconds)
#    - Compute flexural isostasy 124.37 seconds
#    - Writing outputs (1.23 seconds; tNow = -37800000.0)
#    - Compute flexural isostasy 139.97 seconds
# tNow = -37600000.0 (step took 142.29 seconds)
#    - Compute flexural isostasy 141.65 seconds
#    - Writing outputs (1.26 seconds; tNow = -37600000.0)
#    - Compute flexural isostasy 184.33 seconds
# tNow = -37400000.0 (step took 186.78 seconds)
#    - Compute flexural isostasy 156.59 seconds
#    - Writing outputs (1.35 seconds; tNow = -37400000.0)
#    - Compute flexural isostasy 161.70 seconds
# tNow = -37200000.0 (step took 164.40 seconds)
#    - Compute flexural isostasy 152.58 seconds
#    - Writing outputs (1.30 seconds; tNow = -37200000.0)
#    - Compute flexural isostasy 164.74 seconds
# tNow = -37000000.0 (step took 167.37 seconds)
#    - Compute flexural isostasy 141.86 seconds
#    - Writing outputs (1.20 seconds; tNow = -37000000.0)
#    - Compute flexural isostasy 150.59 seconds
# tNow = -36800000.0 (step took 153.12 seconds)
#    - Compute flexural isostasy 141.92 seconds
#    - Writing outputs (1.19 seconds; tNow = -36800000.0)
#    - Compute flexural isostasy 149.94 seconds
# tNow = -36600000.0 (step took 152.30 seconds)
#    - Compute flexural isostasy 120.07 seconds
#    - Writing outputs (1.20 seconds; tNow = -36600000.0)
#    - Compute flexural isostasy 178.27 seconds
# tNow = -36400000.0 (step took 180.50 seconds)
#    - Compute flexural isostasy 148.66 seconds
#    - Writing outputs (1.18 seconds; tNow = -36400000.0)
#    - Compute flexural isostasy 138.55 seconds
# tNow = -36200000.0 (step took 140.91 seconds)
#    - Compute flexural isostasy 130.08 seconds
#    - Writing outputs (1.18 seconds; tNow = -36200000.0)
#    - Compute flexural isostasy 174.55 seconds
# tNow = -36000000.0 (step took 176.89 seconds)
#    - Compute flexural isostasy 156.73 seconds
#    - Writing outputs (1.18 seconds; tNow = -36000000.0)
#    - Compute flexural isostasy 169.19 seconds
# tNow = -35800000.0 (step took 171.75 seconds)
#    - Compute flexural isostasy 152.62 seconds
#    - Writing outputs (1.41 seconds; tNow = -35800000.0)
#    - Compute flexural isostasy 128.82 seconds
# tNow = -35600000.0 (step took 131.15 seconds)
#    - Compute flexural isostasy 131.05 seconds
#    - Writing outputs (1.25 seconds; tNow = -35600000.0)
#    - Compute flexural isostasy 126.73 seconds
# tNow = -35400000.0 (step took 129.17 seconds)
#    - Compute flexural isostasy 142.51 seconds
#    - Writing outputs (1.23 seconds; tNow = -35400000.0)
#    - Compute flexural isostasy 158.38 seconds
# tNow = -35200000.0 (step took 160.68 seconds)
#    - Compute flexural isostasy 163.45 seconds
#    - Writing outputs (1.27 seconds; tNow = -35200000.0)
#    - Compute flexural isostasy 133.29 seconds
# tNow = -35000000.0 (step took 135.78 seconds)
#    - Compute flexural isostasy 171.83 seconds
#    - Writing outputs (1.29 seconds; tNow = -35000000.0)
#    - Compute flexural isostasy 163.90 seconds
# tNow = -34800000.0 (step took 166.51 seconds)
#    - Compute flexural isostasy 170.63 seconds
#    - Writing outputs (1.26 seconds; tNow = -34800000.0)
#    - Compute flexural isostasy 134.37 seconds
# tNow = -34600000.0 (step took 136.80 seconds)
#    - Compute flexural isostasy 116.90 seconds
#    - Writing outputs (1.29 seconds; tNow = -34600000.0)
#    - Compute flexural isostasy 157.17 seconds
# tNow = -34400000.0 (step took 159.48 seconds)
#    - Compute flexural isostasy 137.29 seconds
#    - Writing outputs (1.17 seconds; tNow = -34400000.0)
#    - Compute flexural isostasy 135.42 seconds
# tNow = -34200000.0 (step took 137.60 seconds)
#    - Compute flexural isostasy 153.91 seconds
#    - Writing outputs (1.29 seconds; tNow = -34200000.0)
#    - Compute flexural isostasy 139.34 seconds
# tNow = -34000000.0 (step took 141.83 seconds)
#    - Compute flexural isostasy 171.44 seconds
#    - Writing outputs (1.46 seconds; tNow = -34000000.0)
#    - Compute flexural isostasy 170.04 seconds
# tNow = -33800000.0 (step took 172.98 seconds)
#    - Compute flexural isostasy 204.23 seconds
#    - Writing outputs (1.53 seconds; tNow = -33800000.0)
#    - Compute flexural isostasy 193.44 seconds
# tNow = -33600000.0 (step took 196.26 seconds)
#    - Compute flexural isostasy 214.13 seconds
#    - Writing outputs (1.67 seconds; tNow = -33600000.0)
#    - Compute flexural isostasy 220.64 seconds
# tNow = -33400000.0 (step took 223.58 seconds)
#    - Compute flexural isostasy 198.76 seconds
#    - Writing outputs (1.77 seconds; tNow = -33400000.0)
#    - Compute flexural isostasy 197.87 seconds
# tNow = -33200000.0 (step took 201.26 seconds)
#    - Compute flexural isostasy 221.72 seconds
#    - Writing outputs (1.90 seconds; tNow = -33200000.0)
#    - Compute flexural isostasy 255.31 seconds
# tNow = -33000000.0 (step took 258.93 seconds)
#    - Compute flexural isostasy 301.40 seconds
#    - Writing outputs (1.99 seconds; tNow = -33000000.0)
#    - Compute flexural isostasy 285.56 seconds
# tNow = -32800000.0 (step took 289.35 seconds)
#    - Compute flexural isostasy 277.32 seconds
#    - Writing outputs (2.18 seconds; tNow = -32800000.0)
#    - Compute flexural isostasy 323.07 seconds
# tNow = -32600000.0 (step took 327.10 seconds)
#    - Compute flexural isostasy 299.94 seconds
#    - Writing outputs (2.44 seconds; tNow = -32600000.0)
#    - Compute flexural isostasy 321.27 seconds
# tNow = -32400000.0 (step took 325.49 seconds)
#    - Compute flexural isostasy 343.52 seconds
#    - Writing outputs (2.33 seconds; tNow = -32400000.0)
#    - Compute flexural isostasy 381.21 seconds
# tNow = -32200000.0 (step took 385.22 seconds)
#    - Compute flexural isostasy 282.79 seconds
#    - Writing outputs (2.52 seconds; tNow = -32200000.0)
#    - Compute flexural isostasy 293.95 seconds
# tNow = -32000000.0 (step took 298.33 seconds)
#    - Compute flexural isostasy 324.86 seconds
#    - Writing outputs (2.71 seconds; tNow = -32000000.0)
#    - Compute flexural isostasy 418.04 seconds
# tNow = -31800000.0 (step took 423.16 seconds)
#    - Compute flexural isostasy 394.18 seconds
#    - Writing outputs (3.09 seconds; tNow = -31800000.0)
#    - Compute flexural isostasy 444.22 seconds
# tNow = -31600000.0 (step took 448.26 seconds)
#    - Compute flexural isostasy 255.18 seconds
#    - Writing outputs (2.15 seconds; tNow = -31600000.0)
#    - Compute flexural isostasy 362.43 seconds
# tNow = -31400000.0 (step took 366.26 seconds)
#    - Compute flexural isostasy 241.71 seconds
#    - Writing outputs (2.30 seconds; tNow = -31400000.0)
#    - Compute flexural isostasy 314.44 seconds
# tNow = -31200000.0 (step took 317.40 seconds)
#    - Compute flexural isostasy 173.87 seconds
#    - Writing outputs (1.78 seconds; tNow = -31200000.0)
#    - Compute flexural isostasy 254.61 seconds
# tNow = -31000000.0 (step took 257.93 seconds)
#    - Compute flexural isostasy 181.95 seconds
#    - Writing outputs (1.87 seconds; tNow = -31000000.0)
#    - Compute flexural isostasy 243.43 seconds
# tNow = -30800000.0 (step took 246.51 seconds)
#    - Compute flexural isostasy 260.26 seconds
#    - Writing outputs (1.81 seconds; tNow = -30800000.0)
#    - Compute flexural isostasy 267.69 seconds
# tNow = -30600000.0 (step took 270.72 seconds)
#    - Compute flexural isostasy 292.53 seconds
#    - Writing outputs (1.88 seconds; tNow = -30600000.0)
#    - Compute flexural isostasy 212.37 seconds
# tNow = -30400000.0 (step took 215.71 seconds)
#    - Compute flexural isostasy 216.96 seconds
#    - Writing outputs (2.04 seconds; tNow = -30400000.0)
#    - Compute flexural isostasy 226.13 seconds
# tNow = -30200000.0 (step took 229.58 seconds)
#    - Compute flexural isostasy 206.69 seconds
#    - Writing outputs (2.12 seconds; tNow = -30200000.0)
#    - Compute flexural isostasy 256.40 seconds
# tNow = -30000000.0 (step took 259.96 seconds)
#    - Compute flexural isostasy 274.76 seconds
#    - Writing outputs (2.21 seconds; tNow = -30000000.0)
#    - Compute flexural isostasy 229.67 seconds
# tNow = -29800000.0 (step took 233.00 seconds)
#    - Compute flexural isostasy 221.38 seconds
#    - Writing outputs (2.12 seconds; tNow = -29800000.0)
#    - Compute flexural isostasy 244.89 seconds
# tNow = -29600000.0 (step took 248.63 seconds)
#    - Compute flexural isostasy 232.79 seconds
#    - Writing outputs (2.05 seconds; tNow = -29600000.0)
#    - Compute flexural isostasy 320.31 seconds
# tNow = -29400000.0 (step took 324.03 seconds)
#    - Compute flexural isostasy 278.71 seconds
#    - Writing outputs (2.21 seconds; tNow = -29400000.0)
#    - Compute flexural isostasy 265.54 seconds
# tNow = -29200000.0 (step took 268.63 seconds)
#    - Compute flexural isostasy 310.60 seconds
#    - Writing outputs (2.11 seconds; tNow = -29200000.0)
#    - Compute flexural isostasy 232.77 seconds
# tNow = -29000000.0 (step took 236.02 seconds)
#    - Compute flexural isostasy 248.62 seconds
#    - Writing outputs (2.21 seconds; tNow = -29000000.0)
#    - Compute flexural isostasy 235.84 seconds
# tNow = -28800000.0 (step took 239.10 seconds)
#    - Compute flexural isostasy 208.14 seconds
#    - Writing outputs (1.53 seconds; tNow = -28800000.0)
#    - Compute flexural isostasy 162.79 seconds
# tNow = -28600000.0 (step took 165.23 seconds)
#    - Compute flexural isostasy 168.50 seconds
#    - Writing outputs (1.37 seconds; tNow = -28600000.0)
#    - Compute flexural isostasy 184.92 seconds
# tNow = -28400000.0 (step took 187.18 seconds)
#    - Compute flexural isostasy 183.35 seconds
#    - Writing outputs (1.35 seconds; tNow = -28400000.0)
#    - Compute flexural isostasy 136.20 seconds
# tNow = -28200000.0 (step took 138.60 seconds)
#    - Compute flexural isostasy 172.72 seconds
#    - Writing outputs (1.32 seconds; tNow = -28200000.0)
#    - Compute flexural isostasy 184.34 seconds
# tNow = -28000000.0 (step took 186.75 seconds)
#    - Compute flexural isostasy 177.71 seconds
#    - Writing outputs (1.31 seconds; tNow = -28000000.0)
#    - Compute flexural isostasy 189.18 seconds
# tNow = -27800000.0 (step took 191.48 seconds)
#    - Compute flexural isostasy 123.13 seconds
#    - Writing outputs (1.37 seconds; tNow = -27800000.0)
#    - Compute flexural isostasy 164.30 seconds
# tNow = -27600000.0 (step took 166.69 seconds)
#    - Compute flexural isostasy 142.24 seconds
#    - Writing outputs (1.24 seconds; tNow = -27600000.0)
#    - Compute flexural isostasy 134.02 seconds
# tNow = -27400000.0 (step took 136.34 seconds)
#    - Compute flexural isostasy 126.67 seconds
#    - Writing outputs (1.22 seconds; tNow = -27400000.0)
#    - Compute flexural isostasy 183.00 seconds
# tNow = -27200000.0 (step took 185.55 seconds)
#    - Compute flexural isostasy 151.16 seconds
#    - Writing outputs (1.24 seconds; tNow = -27200000.0)
#    - Compute flexural isostasy 126.20 seconds
# tNow = -27000000.0 (step took 128.46 seconds)
#    - Compute flexural isostasy 162.81 seconds
#    - Writing outputs (1.26 seconds; tNow = -27000000.0)
#    - Compute flexural isostasy 129.72 seconds
# tNow = -26800000.0 (step took 132.05 seconds)
#    - Compute flexural isostasy 119.03 seconds
#    - Writing outputs (1.24 seconds; tNow = -26800000.0)
#    - Compute flexural isostasy 174.05 seconds
# tNow = -26600000.0 (step took 176.28 seconds)
#    - Compute flexural isostasy 154.50 seconds
#    - Writing outputs (1.21 seconds; tNow = -26600000.0)
#    - Compute flexural isostasy 136.04 seconds
# tNow = -26400000.0 (step took 138.37 seconds)
#    - Compute flexural isostasy 138.28 seconds
#    - Writing outputs (1.16 seconds; tNow = -26400000.0)
#    - Compute flexural isostasy 125.72 seconds
# tNow = -26200000.0 (step took 127.89 seconds)
#    - Compute flexural isostasy 148.48 seconds
#    - Writing outputs (1.16 seconds; tNow = -26200000.0)
#    - Compute flexural isostasy 164.84 seconds
# tNow = -26000000.0 (step took 167.00 seconds)
#    - Compute flexural isostasy 123.59 seconds
#    - Writing outputs (1.16 seconds; tNow = -26000000.0)
#    - Compute flexural isostasy 130.02 seconds
# tNow = -25800000.0 (step took 132.09 seconds)
#    - Compute flexural isostasy 160.62 seconds
#    - Writing outputs (1.19 seconds; tNow = -25800000.0)
#    - Compute flexural isostasy 138.41 seconds
# tNow = -25600000.0 (step took 140.74 seconds)
#    - Compute flexural isostasy 158.64 seconds
#    - Writing outputs (1.10 seconds; tNow = -25600000.0)
#    - Compute flexural isostasy 126.63 seconds
# tNow = -25400000.0 (step took 128.61 seconds)
#    - Compute flexural isostasy 151.92 seconds
#    - Writing outputs (1.08 seconds; tNow = -25400000.0)
#    - Compute flexural isostasy 123.00 seconds
# tNow = -25200000.0 (step took 125.04 seconds)
#    - Compute flexural isostasy 132.26 seconds
#    - Writing outputs (1.09 seconds; tNow = -25200000.0)
#    - Compute flexural isostasy 122.24 seconds
# tNow = -25000000.0 (step took 124.20 seconds)
#    - Compute flexural isostasy 131.67 seconds
#    - Writing outputs (1.11 seconds; tNow = -25000000.0)
#    - Compute flexural isostasy 130.16 seconds
# tNow = -24800000.0 (step took 132.17 seconds)
#    - Compute flexural isostasy 165.97 seconds
#    - Writing outputs (1.12 seconds; tNow = -24800000.0)
#    - Compute flexural isostasy 123.17 seconds
# tNow = -24600000.0 (step took 125.13 seconds)
#    - Compute flexural isostasy 127.27 seconds
#    - Writing outputs (1.29 seconds; tNow = -24600000.0)
#    - Compute flexural isostasy 129.28 seconds
# tNow = -24400000.0 (step took 131.55 seconds)
#    - Compute flexural isostasy 110.19 seconds
#    - Writing outputs (1.11 seconds; tNow = -24400000.0)
#    - Compute flexural isostasy 115.20 seconds
# tNow = -24200000.0 (step took 117.29 seconds)
#    - Compute flexural isostasy 118.50 seconds
#    - Writing outputs (1.09 seconds; tNow = -24200000.0)
#    - Compute flexural isostasy 150.65 seconds
# tNow = -24000000.0 (step took 152.73 seconds)
#    - Compute flexural isostasy 149.75 seconds
#    - Writing outputs (1.19 seconds; tNow = -24000000.0)
#    - Compute flexural isostasy 111.29 seconds
# tNow = -23800000.0 (step took 113.46 seconds)
#    - Compute flexural isostasy 145.39 seconds
#    - Writing outputs (1.10 seconds; tNow = -23800000.0)
#    - Compute flexural isostasy 161.31 seconds
# tNow = -23600000.0 (step took 163.49 seconds)
#    - Compute flexural isostasy 110.25 seconds
#    - Writing outputs (1.18 seconds; tNow = -23600000.0)
#    - Compute flexural isostasy 109.71 seconds
# tNow = -23400000.0 (step took 112.01 seconds)
#    - Compute flexural isostasy 160.90 seconds
#    - Writing outputs (1.20 seconds; tNow = -23400000.0)
#    - Compute flexural isostasy 163.55 seconds
# tNow = -23200000.0 (step took 165.77 seconds)
#    - Compute flexural isostasy 109.04 seconds
#    - Writing outputs (1.22 seconds; tNow = -23200000.0)
#    - Compute flexural isostasy 116.27 seconds
# tNow = -23000000.0 (step took 118.59 seconds)
#    - Compute flexural isostasy 104.25 seconds
#    - Writing outputs (1.10 seconds; tNow = -23000000.0)
#    - Compute flexural isostasy 158.18 seconds
# tNow = -22800000.0 (step took 160.51 seconds)
#    - Compute flexural isostasy 152.38 seconds
#    - Writing outputs (1.16 seconds; tNow = -22800000.0)
#    - Compute flexural isostasy 146.46 seconds
# tNow = -22600000.0 (step took 148.71 seconds)
#    - Compute flexural isostasy 122.55 seconds
#    - Writing outputs (1.12 seconds; tNow = -22600000.0)
#    - Compute flexural isostasy 108.67 seconds
# tNow = -22400000.0 (step took 110.87 seconds)
#    - Compute flexural isostasy 122.78 seconds
#    - Writing outputs (1.10 seconds; tNow = -22400000.0)
#    - Compute flexural isostasy 129.59 seconds
# tNow = -22200000.0 (step took 131.81 seconds)
#    - Compute flexural isostasy 106.90 seconds
#    - Writing outputs (1.18 seconds; tNow = -22200000.0)
#    - Compute flexural isostasy 161.30 seconds
# tNow = -22000000.0 (step took 163.52 seconds)
#    - Compute flexural isostasy 108.62 seconds
#    - Writing outputs (1.17 seconds; tNow = -22000000.0)
#    - Compute flexural isostasy 136.51 seconds
# tNow = -21800000.0 (step took 138.65 seconds)
#    - Compute flexural isostasy 122.34 seconds
#    - Writing outputs (1.12 seconds; tNow = -21800000.0)
#    - Compute flexural isostasy 153.80 seconds
# tNow = -21600000.0 (step took 156.15 seconds)
#    - Compute flexural isostasy 101.44 seconds
#    - Writing outputs (1.12 seconds; tNow = -21600000.0)
#    - Compute flexural isostasy 153.04 seconds
# tNow = -21400000.0 (step took 155.22 seconds)
#    - Compute flexural isostasy 149.55 seconds
#    - Writing outputs (1.15 seconds; tNow = -21400000.0)
#    - Compute flexural isostasy 109.27 seconds
# tNow = -21200000.0 (step took 111.59 seconds)
#    - Compute flexural isostasy 151.32 seconds
#    - Writing outputs (1.15 seconds; tNow = -21200000.0)
#    - Compute flexural isostasy 116.42 seconds
# tNow = -21000000.0 (step took 118.39 seconds)
#    - Compute flexural isostasy 124.63 seconds
#    - Writing outputs (1.11 seconds; tNow = -21000000.0)
#    - Compute flexural isostasy 117.13 seconds
# tNow = -20800000.0 (step took 119.12 seconds)
#    - Compute flexural isostasy 125.69 seconds
#    - Writing outputs (1.11 seconds; tNow = -20800000.0)
#    - Compute flexural isostasy 124.45 seconds
# tNow = -20600000.0 (step took 126.84 seconds)
#    - Compute flexural isostasy 124.30 seconds
#    - Writing outputs (1.09 seconds; tNow = -20600000.0)
#    - Compute flexural isostasy 113.01 seconds
# tNow = -20400000.0 (step took 115.15 seconds)
#    - Compute flexural isostasy 121.50 seconds
#    - Writing outputs (1.08 seconds; tNow = -20400000.0)
#    - Compute flexural isostasy 160.70 seconds
# tNow = -20200000.0 (step took 162.91 seconds)
#    - Compute flexural isostasy 113.45 seconds
#    - Writing outputs (1.09 seconds; tNow = -20200000.0)
#    - Compute flexural isostasy 125.53 seconds
# tNow = -20000000.0 (step took 127.75 seconds)
#    - Compute flexural isostasy 160.91 seconds
#    - Writing outputs (1.07 seconds; tNow = -20000000.0)
#    - Compute flexural isostasy 144.45 seconds
# tNow = -19800000.0 (step took 147.45 seconds)
#    - Compute flexural isostasy 158.83 seconds
#    - Writing outputs (1.19 seconds; tNow = -19800000.0)
#    - Compute flexural isostasy 142.58 seconds
# tNow = -19600000.0 (step took 145.14 seconds)
#    - Compute flexural isostasy 121.74 seconds
#    - Writing outputs (1.12 seconds; tNow = -19600000.0)
#    - Compute flexural isostasy 124.66 seconds
# tNow = -19400000.0 (step took 127.62 seconds)
#    - Compute flexural isostasy 124.28 seconds
#    - Writing outputs (1.10 seconds; tNow = -19400000.0)
#    - Compute flexural isostasy 147.29 seconds
# tNow = -19200000.0 (step took 150.23 seconds)
#    - Compute flexural isostasy 140.50 seconds
#    - Writing outputs (1.13 seconds; tNow = -19200000.0)
#    - Compute flexural isostasy 113.50 seconds
# tNow = -19000000.0 (step took 116.30 seconds)
#    - Compute flexural isostasy 160.35 seconds
#    - Writing outputs (1.17 seconds; tNow = -19000000.0)
#    - Compute flexural isostasy 146.27 seconds
# tNow = -18800000.0 (step took 148.62 seconds)
#    - Compute flexural isostasy 128.97 seconds
#    - Writing outputs (1.13 seconds; tNow = -18800000.0)
#    - Compute flexural isostasy 120.27 seconds
# tNow = -18600000.0 (step took 122.53 seconds)
#    - Compute flexural isostasy 165.58 seconds
#    - Writing outputs (1.12 seconds; tNow = -18600000.0)
#    - Compute flexural isostasy 121.85 seconds
# tNow = -18400000.0 (step took 124.47 seconds)
#    - Compute flexural isostasy 112.77 seconds
#    - Writing outputs (1.16 seconds; tNow = -18400000.0)
#    - Compute flexural isostasy 156.98 seconds
# tNow = -18200000.0 (step took 159.59 seconds)
#    - Compute flexural isostasy 104.57 seconds
#    - Writing outputs (1.11 seconds; tNow = -18200000.0)
#    - Compute flexural isostasy 110.79 seconds
# tNow = -18000000.0 (step took 113.29 seconds)
#    - Compute flexural isostasy 150.28 seconds
#    - Writing outputs (1.10 seconds; tNow = -18000000.0)
#    - Compute flexural isostasy 117.93 seconds
# tNow = -17800000.0 (step took 120.17 seconds)
#    - Compute flexural isostasy 118.12 seconds
#    - Writing outputs (1.17 seconds; tNow = -17800000.0)
#    - Compute flexural isostasy 144.11 seconds
# tNow = -17600000.0 (step took 146.34 seconds)
#    - Compute flexural isostasy 117.64 seconds
#    - Writing outputs (1.16 seconds; tNow = -17600000.0)
#    - Compute flexural isostasy 125.67 seconds
# tNow = -17400000.0 (step took 128.25 seconds)
#    - Compute flexural isostasy 153.41 seconds
#    - Writing outputs (1.12 seconds; tNow = -17400000.0)
#    - Compute flexural isostasy 111.68 seconds
# tNow = -17200000.0 (step took 114.11 seconds)
#    - Compute flexural isostasy 150.71 seconds
#    - Writing outputs (1.09 seconds; tNow = -17200000.0)
#    - Compute flexural isostasy 120.61 seconds
# tNow = -17000000.0 (step took 123.02 seconds)
#    - Compute flexural isostasy 126.40 seconds
#    - Writing outputs (1.09 seconds; tNow = -17000000.0)
#    - Compute flexural isostasy 157.17 seconds
# tNow = -16800000.0 (step took 159.77 seconds)
#    - Compute flexural isostasy 146.98 seconds
#    - Writing outputs (1.20 seconds; tNow = -16800000.0)
#    - Compute flexural isostasy 143.92 seconds
# tNow = -16600000.0 (step took 146.27 seconds)
#    - Compute flexural isostasy 154.24 seconds
#    - Writing outputs (1.09 seconds; tNow = -16600000.0)
#    - Compute flexural isostasy 121.49 seconds
# tNow = -16400000.0 (step took 123.81 seconds)
#    - Compute flexural isostasy 124.76 seconds
#    - Writing outputs (1.08 seconds; tNow = -16400000.0)
#    - Compute flexural isostasy 146.32 seconds
# tNow = -16200000.0 (step took 148.58 seconds)
#    - Compute flexural isostasy 139.80 seconds
#    - Writing outputs (1.06 seconds; tNow = -16200000.0)
#    - Compute flexural isostasy 123.97 seconds
# tNow = -16000000.0 (step took 126.76 seconds)
#    - Compute flexural isostasy 128.30 seconds
#    - Writing outputs (1.05 seconds; tNow = -16000000.0)
#    - Compute flexural isostasy 142.24 seconds
# tNow = -15800000.0 (step took 144.86 seconds)
#    - Compute flexural isostasy 132.19 seconds
#    - Writing outputs (1.13 seconds; tNow = -15800000.0)
#    - Compute flexural isostasy 127.77 seconds
# tNow = -15600000.0 (step took 130.06 seconds)
#    - Compute flexural isostasy 128.18 seconds
#    - Writing outputs (1.11 seconds; tNow = -15600000.0)
#    - Compute flexural isostasy 127.54 seconds
# tNow = -15400000.0 (step took 129.86 seconds)
#    - Compute flexural isostasy 131.71 seconds
#    - Writing outputs (1.07 seconds; tNow = -15400000.0)
#    - Compute flexural isostasy 155.08 seconds
# tNow = -15200000.0 (step took 157.22 seconds)
#    - Compute flexural isostasy 127.83 seconds
#    - Writing outputs (1.19 seconds; tNow = -15200000.0)
#    - Compute flexural isostasy 157.87 seconds
# tNow = -15000000.0 (step took 160.77 seconds)
#    - Compute flexural isostasy 107.19 seconds
#    - Writing outputs (1.17 seconds; tNow = -15000000.0)
#    - Compute flexural isostasy 110.68 seconds
# tNow = -14800000.0 (step took 113.68 seconds)
#    - Compute flexural isostasy 122.16 seconds
#    - Writing outputs (1.10 seconds; tNow = -14800000.0)
#    - Compute flexural isostasy 135.32 seconds
# tNow = -14600000.0 (step took 137.88 seconds)
#    - Compute flexural isostasy 107.23 seconds
#    - Writing outputs (1.29 seconds; tNow = -14600000.0)
#    - Compute flexural isostasy 108.81 seconds
# tNow = -14400000.0 (step took 111.32 seconds)
#    - Compute flexural isostasy 105.39 seconds
#    - Writing outputs (1.15 seconds; tNow = -14400000.0)
#    - Compute flexural isostasy 139.16 seconds
# tNow = -14200000.0 (step took 141.76 seconds)
#    - Compute flexural isostasy 151.43 seconds
#    - Writing outputs (1.13 seconds; tNow = -14200000.0)
#    - Compute flexural isostasy 122.74 seconds
# tNow = -14000000.0 (step took 125.13 seconds)
#    - Compute flexural isostasy 137.64 seconds
#    - Writing outputs (1.05 seconds; tNow = -14000000.0)
#    - Compute flexural isostasy 133.65 seconds
# tNow = -13800000.0 (step took 135.93 seconds)
#    - Compute flexural isostasy 122.24 seconds
#    - Writing outputs (1.18 seconds; tNow = -13800000.0)
#    - Compute flexural isostasy 126.49 seconds
# tNow = -13600000.0 (step took 129.15 seconds)
#    - Compute flexural isostasy 103.51 seconds
#    - Writing outputs (1.08 seconds; tNow = -13600000.0)
#    - Compute flexural isostasy 162.84 seconds
# tNow = -13400000.0 (step took 165.34 seconds)
#    - Compute flexural isostasy 119.08 seconds
#    - Writing outputs (1.15 seconds; tNow = -13400000.0)
#    - Compute flexural isostasy 155.70 seconds
# tNow = -13200000.0 (step took 158.22 seconds)
#    - Compute flexural isostasy 128.85 seconds
#    - Writing outputs (1.09 seconds; tNow = -13200000.0)
#    - Compute flexural isostasy 157.39 seconds
# tNow = -13000000.0 (step took 160.00 seconds)
#    - Compute flexural isostasy 117.24 seconds
#    - Writing outputs (1.11 seconds; tNow = -13000000.0)
#    - Compute flexural isostasy 165.85 seconds
# tNow = -12800000.0 (step took 168.67 seconds)
#    - Compute flexural isostasy 122.26 seconds
#    - Writing outputs (1.12 seconds; tNow = -12800000.0)
#    - Compute flexural isostasy 123.86 seconds
# tNow = -12600000.0 (step took 126.40 seconds)
#    - Compute flexural isostasy 118.86 seconds
#    - Writing outputs (1.09 seconds; tNow = -12600000.0)
#    - Compute flexural isostasy 129.60 seconds
# tNow = -12400000.0 (step took 132.19 seconds)
#    - Compute flexural isostasy 114.84 seconds
#    - Writing outputs (1.07 seconds; tNow = -12400000.0)
#    - Compute flexural isostasy 134.41 seconds
# tNow = -12200000.0 (step took 137.05 seconds)
#    - Compute flexural isostasy 117.49 seconds
#    - Writing outputs (1.10 seconds; tNow = -12200000.0)
#    - Compute flexural isostasy 133.67 seconds
# tNow = -12000000.0 (step took 136.38 seconds)
#    - Compute flexural isostasy 120.35 seconds
#    - Writing outputs (1.06 seconds; tNow = -12000000.0)
#    - Compute flexural isostasy 136.48 seconds
# tNow = -11800000.0 (step took 139.43 seconds)
#    - Compute flexural isostasy 111.26 seconds
#    - Writing outputs (1.11 seconds; tNow = -11800000.0)
#    - Compute flexural isostasy 171.64 seconds
# tNow = -11600000.0 (step took 174.45 seconds)
#    - Compute flexural isostasy 110.01 seconds
#    - Writing outputs (1.19 seconds; tNow = -11600000.0)
#    - Compute flexural isostasy 168.28 seconds
# tNow = -11400000.0 (step took 171.19 seconds)
#    - Compute flexural isostasy 117.11 seconds
#    - Writing outputs (1.08 seconds; tNow = -11400000.0)
#    - Compute flexural isostasy 133.78 seconds
# tNow = -11200000.0 (step took 136.66 seconds)
#    - Compute flexural isostasy 135.42 seconds
#    - Writing outputs (1.11 seconds; tNow = -11200000.0)
#    - Compute flexural isostasy 141.21 seconds
# tNow = -11000000.0 (step took 144.18 seconds)
#    - Compute flexural isostasy 121.45 seconds
#    - Writing outputs (1.11 seconds; tNow = -11000000.0)
#    - Compute flexural isostasy 146.80 seconds
# tNow = -10800000.0 (step took 149.96 seconds)
#    - Compute flexural isostasy 145.55 seconds
#    - Writing outputs (1.09 seconds; tNow = -10800000.0)
#    - Compute flexural isostasy 137.65 seconds
# tNow = -10600000.0 (step took 140.65 seconds)
#    - Compute flexural isostasy 119.89 seconds
#    - Writing outputs (1.21 seconds; tNow = -10600000.0)
#    - Compute flexural isostasy 160.45 seconds
# tNow = -10400000.0 (step took 163.66 seconds)
#    - Compute flexural isostasy 154.75 seconds
#    - Writing outputs (1.20 seconds; tNow = -10400000.0)
#    - Compute flexural isostasy 143.43 seconds
# tNow = -10200000.0 (step took 146.75 seconds)
#    - Compute flexural isostasy 148.79 seconds
#    - Writing outputs (1.14 seconds; tNow = -10200000.0)
#    - Compute flexural isostasy 149.30 seconds
# tNow = -10000000.0 (step took 152.38 seconds)
#    - Compute flexural isostasy 120.10 seconds
#    - Writing outputs (1.25 seconds; tNow = -10000000.0)
#    - Compute flexural isostasy 143.33 seconds
# tNow = -9800000.0 (step took 146.29 seconds)
#    - Compute flexural isostasy 122.20 seconds
#    - Writing outputs (1.29 seconds; tNow = -9800000.0)
#    - Compute flexural isostasy 109.41 seconds
# tNow = -9600000.0 (step took 112.64 seconds)
#    - Compute flexural isostasy 120.30 seconds
#    - Writing outputs (1.13 seconds; tNow = -9600000.0)
#    - Compute flexural isostasy 118.71 seconds
# tNow = -9400000.0 (step took 121.92 seconds)
#    - Compute flexural isostasy 107.85 seconds
#    - Writing outputs (1.16 seconds; tNow = -9400000.0)
#    - Compute flexural isostasy 122.99 seconds
# tNow = -9200000.0 (step took 126.08 seconds)
#    - Compute flexural isostasy 118.58 seconds
#    - Writing outputs (1.10 seconds; tNow = -9200000.0)
#    - Compute flexural isostasy 137.99 seconds
# tNow = -9000000.0 (step took 141.04 seconds)
#    - Compute flexural isostasy 140.18 seconds
#    - Writing outputs (1.09 seconds; tNow = -9000000.0)
#    - Compute flexural isostasy 133.23 seconds
# tNow = -8800000.0 (step took 136.31 seconds)
#    - Compute flexural isostasy 145.20 seconds
#    - Writing outputs (1.13 seconds; tNow = -8800000.0)
#    - Compute flexural isostasy 113.10 seconds
# tNow = -8600000.0 (step took 116.18 seconds)
#    - Compute flexural isostasy 136.32 seconds
#    - Writing outputs (1.10 seconds; tNow = -8600000.0)
#    - Compute flexural isostasy 159.12 seconds
# tNow = -8400000.0 (step took 162.16 seconds)
#    - Compute flexural isostasy 106.92 seconds
#    - Writing outputs (1.11 seconds; tNow = -8400000.0)
#    - Compute flexural isostasy 134.63 seconds
# tNow = -8200000.0 (step took 137.66 seconds)
#    - Compute flexural isostasy 149.80 seconds
#    - Writing outputs (1.14 seconds; tNow = -8200000.0)
#    - Compute flexural isostasy 140.46 seconds
# tNow = -8000000.0 (step took 143.67 seconds)
#    - Compute flexural isostasy 121.22 seconds
#    - Writing outputs (1.12 seconds; tNow = -8000000.0)
#    - Compute flexural isostasy 139.46 seconds
# tNow = -7800000.0 (step took 142.64 seconds)
#    - Compute flexural isostasy 133.28 seconds
#    - Writing outputs (1.24 seconds; tNow = -7800000.0)
#    - Compute flexural isostasy 156.53 seconds
# tNow = -7600000.0 (step took 159.78 seconds)
#    - Compute flexural isostasy 117.95 seconds
#    - Writing outputs (1.12 seconds; tNow = -7600000.0)
#    - Compute flexural isostasy 113.05 seconds
# tNow = -7400000.0 (step took 116.31 seconds)
#    - Compute flexural isostasy 126.08 seconds
#    - Writing outputs (1.11 seconds; tNow = -7400000.0)
#    - Compute flexural isostasy 154.09 seconds
# tNow = -7200000.0 (step took 157.32 seconds)
#    - Compute flexural isostasy 110.62 seconds
#    - Writing outputs (1.13 seconds; tNow = -7200000.0)
#    - Compute flexural isostasy 116.06 seconds
# tNow = -7000000.0 (step took 119.16 seconds)
#    - Compute flexural isostasy 109.50 seconds
#    - Writing outputs (1.13 seconds; tNow = -7000000.0)
#    - Compute flexural isostasy 137.32 seconds
# tNow = -6800000.0 (step took 140.42 seconds)
#    - Compute flexural isostasy 125.40 seconds
#    - Writing outputs (1.17 seconds; tNow = -6800000.0)
#    - Compute flexural isostasy 121.22 seconds
# tNow = -6600000.0 (step took 124.41 seconds)
#    - Compute flexural isostasy 143.61 seconds
#    - Writing outputs (1.07 seconds; tNow = -6600000.0)
#    - Compute flexural isostasy 131.83 seconds
# tNow = -6400000.0 (step took 134.99 seconds)
#    - Compute flexural isostasy 148.19 seconds
#    - Writing outputs (1.06 seconds; tNow = -6400000.0)
#    - Compute flexural isostasy 114.46 seconds
# tNow = -6200000.0 (step took 117.62 seconds)
#    - Compute flexural isostasy 114.47 seconds
#    - Writing outputs (1.13 seconds; tNow = -6200000.0)
#    - Compute flexural isostasy 141.91 seconds
# tNow = -6000000.0 (step took 145.09 seconds)
#    - Compute flexural isostasy 151.34 seconds
#    - Writing outputs (1.17 seconds; tNow = -6000000.0)
#    - Compute flexural isostasy 116.00 seconds
# tNow = -5802102.0 (step took 119.08 seconds)
#    - Compute flexural isostasy 112.73 seconds
#    - Writing outputs (1.17 seconds; tNow = -5800000.0)
#    - Compute flexural isostasy 111.73 seconds
# tNow = -5600000.0 (step took 113.93 seconds)
#    - Compute flexural isostasy 122.14 seconds
#    - Writing outputs (1.08 seconds; tNow = -5600000.0)
#    - Compute flexural isostasy 138.26 seconds
# tNow = -5400000.0 (step took 140.48 seconds)
#    - Compute flexural isostasy 119.75 seconds
#    - Writing outputs (1.10 seconds; tNow = -5400000.0)
#    - Compute flexural isostasy 155.75 seconds
# tNow = -5200000.0 (step took 157.98 seconds)
#    - Compute flexural isostasy 137.47 seconds
#    - Writing outputs (1.12 seconds; tNow = -5200000.0)
#    - Compute flexural isostasy 173.27 seconds
# tNow = -5000000.0 (step took 175.48 seconds)
#    - Compute flexural isostasy 152.31 seconds
#    - Writing outputs (1.14 seconds; tNow = -5000000.0)
#    - Compute flexural isostasy 150.48 seconds
# tNow = -4800000.0 (step took 152.97 seconds)
#    - Compute flexural isostasy 147.21 seconds
#    - Writing outputs (1.16 seconds; tNow = -4800000.0)
#    - Compute flexural isostasy 123.49 seconds
# tNow = -4600000.0 (step took 126.05 seconds)
#    - Compute flexural isostasy 105.79 seconds
#    - Writing outputs (1.15 seconds; tNow = -4600000.0)
#    - Compute flexural isostasy 137.74 seconds
# tNow = -4400000.0 (step took 140.35 seconds)
#    - Compute flexural isostasy 103.57 seconds
#    - Writing outputs (1.14 seconds; tNow = -4400000.0)
#    - Compute flexural isostasy 155.21 seconds
# tNow = -4200000.0 (step took 158.48 seconds)
#    - Compute flexural isostasy 159.31 seconds
#    - Writing outputs (1.20 seconds; tNow = -4200000.0)
#    - Compute flexural isostasy 165.91 seconds
# tNow = -4001192.0 (step took 169.26 seconds)
#    - Compute flexural isostasy 109.53 seconds
#    - Writing outputs (1.11 seconds; tNow = -4000000.0)
#    - Compute flexural isostasy 161.02 seconds
# tNow = -3800000.0 (step took 163.80 seconds)
#    - Compute flexural isostasy 166.53 seconds
#    - Writing outputs (1.32 seconds; tNow = -3800000.0)
#    - Compute flexural isostasy 115.89 seconds
# tNow = -3600000.0 (step took 118.55 seconds)
#    - Compute flexural isostasy 163.04 seconds
#    - Writing outputs (1.23 seconds; tNow = -3600000.0)
#    - Compute flexural isostasy 165.38 seconds
# tNow = -3400000.0 (step took 168.17 seconds)
#    - Compute flexural isostasy 169.69 seconds
#    - Writing outputs (1.17 seconds; tNow = -3400000.0)
#    - Compute flexural isostasy 135.01 seconds
# tNow = -3215478.0 (step took 137.75 seconds)
#    - Compute flexural isostasy 147.68 seconds
#    - Writing outputs (1.30 seconds; tNow = -3200000.0)
#    - Compute flexural isostasy 133.28 seconds
# tNow = -3011264.0 (step took 136.23 seconds)
#    - Compute flexural isostasy 146.72 seconds
#    - Writing outputs (1.27 seconds; tNow = -3000000.0)
#    - Compute flexural isostasy 134.37 seconds
# tNow = -2800000.0 (step took 137.17 seconds)
#    - Compute flexural isostasy 148.45 seconds
#    - Writing outputs (1.26 seconds; tNow = -2800000.0)
#    - Compute flexural isostasy 147.25 seconds
# tNow = -2606140.0 (step took 150.41 seconds)
#    - Compute flexural isostasy 177.40 seconds
#    - Writing outputs (1.21 seconds; tNow = -2600000.0)
#    - Compute flexural isostasy 158.62 seconds
# tNow = -2405720.0 (step took 161.62 seconds)
#    - Compute flexural isostasy 180.37 seconds
#    - Writing outputs (1.25 seconds; tNow = -2400000.0)
#    - Compute flexural isostasy 137.78 seconds
# tNow = -2200000.0 (step took 140.48 seconds)
#    - Compute flexural isostasy 153.52 seconds
#    - Writing outputs (1.22 seconds; tNow = -2200000.0)
#    - Compute flexural isostasy 161.95 seconds
# tNow = -2000000.0 (step took 164.76 seconds)
#    - Compute flexural isostasy 140.95 seconds
#    - Writing outputs (1.22 seconds; tNow = -2000000.0)
#    - Compute flexural isostasy 130.06 seconds
# tNow = -1800000.0 (step took 133.10 seconds)
#    - Compute flexural isostasy 149.03 seconds
#    - Writing outputs (1.29 seconds; tNow = -1800000.0)
#    - Compute flexural isostasy 140.49 seconds
# tNow = -1600000.0 (step took 143.66 seconds)
#    - Compute flexural isostasy 112.16 seconds
#    - Writing outputs (1.35 seconds; tNow = -1600000.0)
#    - Compute flexural isostasy 112.68 seconds
# tNow = -1400000.0 (step took 115.55 seconds)
#    - Compute flexural isostasy 151.62 seconds
#    - Writing outputs (1.27 seconds; tNow = -1400000.0)
#    - Compute flexural isostasy 172.58 seconds
# tNow = -1200000.0 (step took 175.40 seconds)
#    - Compute flexural isostasy 158.78 seconds
#    - Writing outputs (1.15 seconds; tNow = -1200000.0)
#    - Compute flexural isostasy 129.93 seconds
# tNow = -1000000.0 (step took 132.54 seconds)
#    - Compute flexural isostasy 173.89 seconds
#    - Writing outputs (1.20 seconds; tNow = -1000000.0)
#    - Compute flexural isostasy 133.56 seconds
# tNow = -816458.0 (step took 136.03 seconds)
#    - Compute flexural isostasy 139.59 seconds
#    - Writing outputs (1.28 seconds; tNow = -800000.0)
#    - Compute flexural isostasy 136.90 seconds
# tNow = -616634.0 (step took 139.58 seconds)
#    - Compute flexural isostasy 137.50 seconds
#    - Writing outputs (1.20 seconds; tNow = -600000.0)
#    - Compute flexural isostasy 134.79 seconds
# tNow = -417414.0 (step took 137.39 seconds)
#    - Compute flexural isostasy 144.00 seconds
#    - Writing outputs (1.21 seconds; tNow = -400000.0)
#    - Compute flexural isostasy 141.60 seconds
# tNow = -220966.0 (step took 143.97 seconds)
#    - Compute flexural isostasy 137.31 seconds
#    - Writing outputs (1.32 seconds; tNow = -200000.0)
#    - Compute flexural isostasy 120.58 seconds
# tNow = 0.0 (123.84 seconds)
#    - Compute flexural isostasy 118.47 seconds
#    - Writing outputs (1.24 seconds; tNow = 0.0)

# %%
591*400*3
